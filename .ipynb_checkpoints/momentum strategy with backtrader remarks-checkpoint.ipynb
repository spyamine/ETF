# %% [markdown]
# In this post we will look at the momentum strategy from Andreas F. Clenow's book [Stocks on the Move: Beating the Market with Hedge Fund Momentum Strategy](https://amzn.to/2YzEIvL) and backtest its performance using the survivorship bias-free dataset we created in my [last post](/2019/05/creating-a-survivorship-bias-free-sp-500-dataset-with-python/).

# %% [markdown]
# Momentum strategies are almost the opposite of mean-reversion strategies. A typical momentum strategy will buy stocks that have been showing an upward trend in hopes that the trend will continue. The momentum strategy defined in Clenow's books trades based upon the following rules:

# %% [markdown]
#  * Trade once a week. In his book, Clenow trades every Wednesday, but as he notes, which day is completely arbitrary.
#
#
#  * Rank stocks in the S&P 500 based on momentum. Momentum is calculated by multiplying the annualized exponential regression slope of the past 90 days by the $R^2$ coefficient of the regression calculation.
#
#
#  * Position size is calculated using the 20-day [Average True Range](https://www.investopedia.com/terms/a/atr.asp) of each stock, multiplied by 10 basis points of the portfolio value.
#
#
#  * Only open new positions if the S&P 500 is above its 200-day moving average.
#
#
#  * Every week, look to sell stocks that are not in the top 20% momentum ranking, or have fallen below their 100 day moving average. Buy stocks in the top 20% momentum rankings with remaining cash.
#
#
#  * Every other week, rebalance existing positions with updated Average True Range values.

# %% [markdown]
# Before we backtest the strategy, let's look into the momentum and position size formulas.

# %% [markdown]
# ## Momentum

# %% [markdown]
# As mentioned above, momentum is calculated by multiplying the annualized exponential regression slope of the past 90 days by the $R^2$ coefficient of the regression calculation. To see this in action, let's look at the highest momentum values measured in our dataset. First we'll need to load in the dataset:

# %%
from datetime import datetime 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.rcParams["figure.figsize"] = (10, 6) # (w, h)
plt.ioff()

# %%
from glob import glob

# %%
tickers = glob("survivorship-free/data/*.csv")
# remove the full path
tickers = [ ticker.split("/")[2].split(".")[0]  for ticker in tickers]
# remove the 'tickers' from the list

tickers.remove('tickers')
# print (tickers)

# %%
# tickers = pd.read_csv('survivorship-free/data/tickers.csv', header=None)[1].tolist()

stocks = (
    (pd.concat(
        [pd.read_csv(f"survivorship-free/data/{ticker}.csv", index_col='date', parse_dates=True)[
            'close'
        ].rename(ticker)
        for ticker in tickers],
        axis=1,
        sort=True)
    )
)
stocks = stocks.loc[:,~stocks.columns.duplicated()]

# %%
print (stocks.tail())
# Out:
#              CSCO    UAL    TROW    ISRG   PRGO    LUK    TPR    DVN  NU  \
# date
# 2018-02-22  42.94  66.70  110.42  419.79  87.07  24.48  49.77  30.41 NaN
# 2018-02-23  44.00  67.57  112.30  427.51  88.25  24.97  50.65  31.43 NaN
# 2018-02-26  45.36  69.26  114.15  432.00  88.30  25.02  51.16  31.61 NaN
# 2018-02-27  45.04  67.86  112.39  430.98  82.00  24.56  50.65  31.86 NaN
# 2018-02-28    NaN    NaN     NaN     NaN    NaN    NaN    NaN    NaN NaN
#
#               MRO  ...    TSS     CRM    PGR     WAT    BWA    LRCX    NWL  \
# date               ...
# 2018-02-22  15.18  ...  86.80  113.00  56.85  204.47  52.24  188.36  26.71
# 2018-02-23  15.54  ...  88.82  114.96  57.71  208.47  52.32  193.10  26.80
# 2018-02-26  15.34  ...  88.85  116.65  58.85  208.45  51.91  198.43  27.82
# 2018-02-27  15.00  ...  87.99  116.47  58.53  206.11  50.09  193.47  26.96
# 2018-02-28    NaN  ...    NaN     NaN    NaN     NaN    NaN     NaN    NaN
#
#             UAA     BLK    PPL
# date
# 2018-02-22  NaN  539.53  29.52
# 2018-02-23  NaN  549.75  30.34
# 2018-02-26  NaN  563.97  29.82
# 2018-02-27  NaN  552.77  29.17
# 2018-02-28  NaN     NaN    NaN
#
# [5 rows x 638 columns]

# %% [markdown]
# Now let's create our momentum measurement function. We can compute the exponential regression of a stock by performing linear regression on the natural log of the stock's daily closes:

# %%
from scipy.stats import linregress
def momentum(closes):
    returns = np.log(closes)
    x = np.arange(len(returns))
    slope, _, rvalue, _, _ = linregress(x, returns)
    return ((1 + slope) ** 252) * (rvalue ** 2)  # annualize slope and multiply by R^2

# %% [markdown]
# Now we can apply a rolling 90 day momentum calculation to all of the stocks in our universe:

# %%
momentums = stocks.copy(deep=True)
for ticker in tickers:
    momentums[ticker] = stocks[ticker].rolling(90).apply(momentum, raw=False)

# %% [markdown]
# Let's look at the 5 stocks with the best momentum values and plot them along with their regression curve.

# %% [markdown]
# ## Risk Parity Sizing

# %% [markdown]
# Clenow's strategy uses risk parity allocation to calculate the position sizes of each stock. Each stock is assigned a size using the following formula:

# %% [markdown]
# {% raw %}
# $$Size = {{AccountValue\times RiskFactor} \over {{ATR}_{20}}}$$
# {% endraw %}

# %% [markdown]
# Where ${ATR}_{20}$ is a stock's [Average True Range](https://www.investopedia.com/terms/a/atr.asp) over the past 20 days. The risk factor, in our case, will be 10 basis points (0.1%). This means that if we assume each stock's ATR remains similar in the future, we can expect each stock to have a daily impact of 0.1% of our portfolio. We are essentially normalizing the weights all of the stocks in our portfolio by risk.

# %% [markdown]
# Now that we understand how the strategy works, let's backtest it!

# %% [markdown]
# # Backtesting

# %% [markdown]
# First we'll code the `Momentum` indicator and our strategy:

# %%
import backtrader as bt
from scipy.stats import linregress
import collections

# %%
# in order to have a purely declarative indicator
# 1- we build a function that computes it
# 2- use bt.ind.OperationN indicator which must have an attribute func defined, which will get period bars passed as argument 
# and will put the return value into the defined line 



class Momentum(bt.Indicator):
    lines = ('trend',)
    #     With a tuple of tuples parameters retain the order of declaration, 
    #     which can be of importance when enumerating them.
    params = dict(period = 90) # or params = (('period', 90),)
    
    def __init__(self):
        self.addminperiod(self.params.period)
        
    def next(self):
        returns = np.log(self.data.get(size=self.p.period))
        x = np.arange(len(returns))
        slope, _, rvalue, _, _ = linregress(x, returns)
        annualized = (1 + slope) ** 252
        self.lines.trend[0] = annualized * (rvalue ** 2)

class Momentum2(bt.ind.PeriodN):
    lines = ('trend',)
    #     With a tuple of tuples parameters retain the order of declaration, 
    #     which can be of importance when enumerating them.
    params = dict(period = 90) # or params = (('period', 90),)

    def next(self):
        returns = np.log(self.data.get(size=self.p.period))
        x = np.arange(len(returns))
        slope, _, rvalue, _, _ = linregress(x, returns)
        annualized = (1 + slope) ** 252
        self.lines.trend[0] = annualized * (rvalue ** 2)

def momentum_func(prices):
    returns = np.log(prices)
    slope, _ , rvalue, _ , _ = linregress(np.arange(len(r)),r)
    annualized = (1 + slope)**252
    return annualized*(rvalue **2)

class Momentum3(bt.ind.OperationN):
    lines =('trend',)
    params = dict(period=50)
    func = momentum_func

# %%
def dayName(day):
    day_name= ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday','Sunday']
    return (day_name[day.weekday()]) 

dayName(datetime.today())
# Out:
# 'Sunday'

# %%
# import datetime


class Strategy(bt.Strategy):
    params = dict(
        rankingPerc = 0.20,
        
        riskFactor = 0.001,
        
        momentum  = Momentum, # parametrize the momentum and its period
        momentum_period = 90,
        
        movav = bt.ind.SMA, # parametrize the moving average and its periods
        idx_period = 200,
        
        stock_period = 100,
        
        volatr = bt.ind.ATR, # parametrize the volatility and its period
        vol_period = 20,  
        
        rebal_weekday = 5, # rebalance 5 is friday
    )
    
    def __init__(self):
#         self.i = 0
        self.timer_counter = 1
        self.inds = collections.defaultdict(dict)
        
        self.index = self.datas[0]
        self.stocks = self.datas[1:]
        
        self.idx_mav = self.p.movav(self.index,period = self.p.idx_period) # bt.indicators.SimpleMovingAverage(self.spy.close,
#                                                             period=200)
        self.index_filter = self.index < self.idx_mav

        for d in self.stocks:
#             self.inds[d] = {}
            self.inds[d]["mom"] = self.p.momentum(d,period=self.p.momentum_period)
            self.inds[d]["mav"] = self.p.movav(d,period=self.p.stock_period)
            self.inds[d]["vol"] = self.p.volatr(d,period=self.p.vol_period)
            self.inds[d]["sma_signal"] = d - self.inds[d]["mav"] #  self.p.volatr(d,period=self.p.vol_period)
        
        self.d_with_len = [] # data with len required to make computations
        
        self.add_timer(
            when = bt.Timer.SESSION_START,
            weekdays=[self.p.rebal_weekday],
            weekcarry=True, # if a day isn't there, execute on the next
            cheat = True,
        )
        
#         self.add_timer(
#             when = bt.Timer.SESSION_START,
#             weekdays=[self.p.rebal_weekday],
#             weekcarry=True, # if a day isn't there, execute on the next
#         )
        
    def prenext(self):
        # call next() even when data is not available for all tickers
        
        self.d_with_len = [d for d in self.stocks if len(d)]
        self.next()
        # but there is no safeguard when entering next
        # all the data is not necessaraly available.
        # the default behavior for next when is called by backtrader is that it waits for all the data to be available
    
    
    def nextstart(self):
        # This is called exactly ONCE, when next is 1st called and defaults to
        # call `next`
        self.d_with_len = self.datas  # all data sets fulfill the guarantees now

        self.next()  
        
    
    def next(self):
        pass
        
#         _, isowk, isowkday = self.datetime.date().isocalendar()
#         txt = '{}, {}, isowk {}, isowkday {}'.format(len(self), self.datetime.datetime(), isowk, isowkday)
#         print(txt)
        
        
        
#         self.rankings = list(filter(lambda d: len(d) , self.stocks))
# #         self.rankings = list(filter(lambda d: len(d) > 100, self.stocks))
#         print ("rankings length: {}".format(len(self.rankings)))
#         self.rankings.sort(key=lambda d: self.inds[d]["mom"][0])
#         self.num_stocks = len(self.rankings)
        
        
#         bars_count = len(self) # counts how many bars passed
#         print ("i: {}, len(bar): {} ".format(self.i,len(self)))
        
#         if bars_count % 5 == 0:
#             self.rebalance_portfolio()
#         if bars_count % 10 == 0:
#             self.rebalance_positions()
            
#         if self.i % 5 == 0:
#             self.rebalance_portfolio()
#         if self.i % 10 == 0:
#             self.rebalance_positions()
#         self.i += 1
        
        


    def notify_timer(self,timer,when,*args,**kwargs):
        
        print ('strategy notify_timer with tid {}, when {}'.
              format(timer.p.tid,when))
        
        self.rankings = list(filter(lambda d: len(d) , self.stocks))
#         self.rankings = list(filter(lambda d: len(d) > 100, self.stocks))
        print ("rankings length: {}".format(len(self.rankings)))
        self.rankings.sort(key=lambda d: self.inds[d]["mom"][0])
        self.num_stocks = len(self.rankings)
        
        print ("self.num_stocks: {}".format(self.num_stocks))
        
        if self.num_stocks > 0 :
            
             _, isowk, isowkday = self.datetime.date().isocalendar()
                
#             day_name = dayName(self.datetime.date())
            
            day_name = ""
            
            txt = 'number of bars passed: {}, current date: {}, isowk: {}, isowkday: {}, day name: {}'.format(len(self), self.datetime.datetime(), isowk, isowkday, day_name)
            
            print (txt)
            
            if self.timer_counter % 2 == 0 :
                print ("rebalance_portfolio...")
                self.rebalance_portfolio()
                print ("rebalance_portfolio... done")
            else:
                print ("rebalance_positions")
                self.rebalance_positions()
                print ("rebalance_positions... done")
        
        self.timer_counter +=1

        

    
    def rebalance_portfolio(self):
        # only look at data that we can have indicators for 
#         self.rankings = list(filter(lambda d: len(d) > 100, self.stocks))
#         self.rankings.sort(key=lambda d: self.inds[d]["mom"][0])
#         num_stocks = len(self.rankings)
        
        # sell stocks based on criteria
        for i, d in enumerate(self.rankings):
            if self.getposition(self.data).size:
                if i > self.num_stocks * self.p.rankingPerc or self.inds[d]["sma_signal"]:
                    self.close(d)
        
        if self.index_filter:
            return
        
        # buy stocks with remaining cash
        for i, d in enumerate(self.rankings[:int(self.num_stocks * self.p.rankingPerc)]):
            cash = self.broker.get_cash()
            value = self.broker.get_value()
            if cash <= 0:
                break
            if not self.getposition(self.data).size:
                size = value * self.p.riskFactor / self.inds[d]["vol"]
                self.buy(d, size=size)
                
        
    def rebalance_positions(self):
#         num_stocks = len(self.rankings)
        
        if self.index_filter:
            return

        # rebalance all stocks
        for i, d in enumerate(self.rankings[:int(self.num_stocks * 0.2)]):
            cash = self.broker.get_cash()
            value = self.broker.get_value()
            if cash <= 0:
                break
            size = value * self.p.riskFactor / self.inds[d]["vol"]
            self.order_target_size(d, size)

# %% [markdown]
# As we can see in the code, the strategy looks for stocks it needs to sell every week in the `rebalance_portfolio` method and rebalances all of its positions every other week in the `rebalance_positions` method. Now let's run a backtest!

# %%
cerebro = bt.Cerebro(stdstats=False)
cerebro.broker.set_coc(True)

spy = bt.feeds.YahooFinanceData(dataname='SPY',
                                 fromdate=datetime(2012,2,28),
                                 todate=datetime(2018,2,28),
                                 plot=False)

cerebro.adddata(spy)  # add S&P 500 Index

print ("loading the data ...")
for ticker in tickers:
    df = pd.read_csv(f"survivorship-free/data/{ticker}.csv",
                     parse_dates=True,
                     index_col=0)
    if len(df) > 100: # data must be long enough to compute 100 day SMA
isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-05-10 00:00:00
# rankings length: 456
# self.num_stocks: 456
# rebalance_positions
# 351, 2013-05-09 23:59:59.999989, isowk 19, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-05-17 00:00:00
# rankings length: 456
# self.num_stocks: 456
# rebalance_portfolio
# 361, 2013-05-16 23:59:59.999989, isowk 20, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-05-24 00:00:00
# rankings length: 456
# self.num_stocks: 456
# rebalance_positions
# 371, 2013-05-23 23:59:59.999989, isowk 21, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-05-31 00:00:00
# rankings length: 459
# self.num_stocks: 459
# rebalance_portfolio
# 379, 2013-05-30 23:59:59.999989, isowk 22, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-06-07 00:00:00
# rankings length: 459
# self.num_stocks: 459
# rebalance_positions
# 389, 2013-06-06 23:59:59.999989, isowk 23, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-06-14 00:00:00
# rankings length: 459
# self.num_stocks: 459
# rebalance_portfolio
# 399, 2013-06-13 23:59:59.999989, isowk 24, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-06-21 00:00:00
# rankings length: 459
# self.num_stocks: 459
# rebalance_positions
# 409, 2013-06-20 23:59:59.999989, isowk 25, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-06-28 00:00:00
# rankings length: 461
# self.num_stocks: 461
# rebalance_portfolio
# 419, 2013-06-27 23:59:59.999989, isowk 26, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-07-05 00:00:00
# rankings length: 461
# self.num_stocks: 461
# rebalance_positions
# 427, 2013-07-03 23:59:59.999989, isowk 27, isowkday 3, dayName: Wednesday
# strategy notify_timer with tid 0, when 2013-07-12 00:00:00
# rankings length: 461
# self.num_stocks: 461
# rebalance_portfolio
# 437, 2013-07-11 23:59:59.999989, isowk 28, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-07-19 00:00:00
# rankings length: 461
# self.num_stocks: 461
# rebalance_positions
# 447, 2013-07-18 23:59:59.999989, isowk 29, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-07-26 00:00:00
# rankings length: 461
# self.num_stocks: 461
# rebalance_portfolio
# 457, 2013-07-25 23:59:59.999989, isowk 30, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-08-02 00:00:00
# rankings length: 464
# self.num_stocks: 464
# rebalance_positions
# 467, 2013-08-01 23:59:59.999989, isowk 31, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-08-09 00:00:00
# rankings length: 464
# self.num_stocks: 464
# rebalance_portfolio
# 477, 2013-08-08 23:59:59.999989, isowk 32, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-08-16 00:00:00
# rankings length: 464
# self.num_stocks: 464
# rebalance_positions
# 487, 2013-08-15 23:59:59.999989, isowk 33, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-08-23 00:00:00
# rankings length: 464
# self.num_stocks: 464
# rebalance_portfolio
# 497, 2013-08-22 23:59:59.999989, isowk 34, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-08-30 00:00:00
# rankings length: 464
# self.num_stocks: 464
# rebalance_positions
# 507, 2013-08-29 23:59:59.999989, isowk 35, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-09-06 00:00:00
# rankings length: 464
# self.num_stocks: 464
# rebalance_portfolio
# 515, 2013-09-05 23:59:59.999989, isowk 36, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-09-13 00:00:00
# rankings length: 464
# self.num_stocks: 464
# rebalance_positions
# 525, 2013-09-12 23:59:59.999989, isowk 37, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-09-20 00:00:00
# rankings length: 464
# self.num_stocks: 464
# rebalance_portfolio
# 535, 2013-09-19 23:59:59.999989, isowk 38, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-09-27 00:00:00
# rankings length: 464
# self.num_stocks: 464
# rebalance_positions
# 545, 2013-09-26 23:59:59.999989, isowk 39, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-10-04 00:00:00
# rankings length: 467
# self.num_stocks: 467
# rebalance_portfolio
# 555, 2013-10-03 23:59:59.999989, isowk 40, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-10-11 00:00:00
# rankings length: 467
# self.num_stocks: 467
# rebalance_positions
# 565, 2013-10-10 23:59:59.999989, isowk 41, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-10-18 00:00:00
# rankings length: 467
# self.num_stocks: 467
# rebalance_portfolio
# 575, 2013-10-17 23:59:59.999989, isowk 42, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-10-25 00:00:00
# rankings length: 467
# self.num_stocks: 467
# rebalance_positions
# 585, 2013-10-24 23:59:59.999989, isowk 43, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-11-01 00:00:00
# rankings length: 469
# self.num_stocks: 469
# rebalance_portfolio
# 595, 2013-10-31 23:59:59.999989, isowk 44, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-11-08 00:00:00
# rankings length: 469
# self.num_stocks: 469
# rebalance_positions
# 605, 2013-11-07 23:59:59.999989, isowk 45, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-11-15 00:00:00
# rankings length: 469
# self.num_stocks: 469
# rebalance_portfolio
# 615, 2013-11-14 23:59:59.999989, isowk 46, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-11-22 00:00:00
# rankings length: 469
# self.num_stocks: 469
# rebalance_positions
# 625, 2013-11-21 23:59:59.999989, isowk 47, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-11-29 00:00:00
# rankings length: 470
# self.num_stocks: 470
# rebalance_portfolio
# 633, 2013-11-27 23:59:59.999989, isowk 48, isowkday 3, dayName: Wednesday
# strategy notify_timer with tid 0, when 2013-12-06 00:00:00
# rankings length: 470
# self.num_stocks: 470
# rebalance_positions
# 643, 2013-12-05 23:59:59.999989, isowk 49, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-12-13 00:00:00
# rankings length: 470
# self.num_stocks: 470
# rebalance_portfolio
# 653, 2013-12-12 23:59:59.999989, isowk 50, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-12-20 00:00:00
# rankings length: 470
# self.num_stocks: 470
# rebalance_positions
# 663, 2013-12-19 23:59:59.999989, isowk 51, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2013-12-27 00:00:00
# rankings length: 470
# self.num_stocks: 470
# rebalance_portfolio
# 671, 2013-12-26 23:59:59.999989, isowk 52, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-01-03 00:00:00
# rankings length: 474
# self.num_stocks: 474
# rebalance_positions
# 679, 2014-01-02 23:59:59.999989, isowk 1, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-01-10 00:00:00
# rankings length: 474
# self.num_stocks: 474
# rebalance_portfolio
# 689, 2014-01-09 23:59:59.999989, isowk 2, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-01-17 00:00:00
# rankings length: 474
# self.num_stocks: 474
# rebalance_positions
# 699, 2014-01-16 23:59:59.999989, isowk 3, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-01-24 00:00:00
# rankings length: 474
# self.num_stocks: 474
# rebalance_portfolio
# 707, 2014-01-23 23:59:59.999989, isowk 4, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-01-31 00:00:00
# rankings length: 475
# self.num_stocks: 475
# rebalance_positions
# 717, 2014-01-30 23:59:59.999989, isowk 5, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-02-07 00:00:00
# rankings length: 475
# self.num_stocks: 475
# rebalance_portfolio
# 727, 2014-02-06 23:59:59.999989, isowk 6, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-02-14 00:00:00
# rankings length: 475
# self.num_stocks: 475
# rebalance_positions
# 737, 2014-02-13 23:59:59.999989, isowk 7, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-02-21 00:00:00
# rankings length: 475
# self.num_stocks: 475
# rebalance_portfolio
# 745, 2014-02-20 23:59:59.999989, isowk 8, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-02-28 00:00:00
# rankings length: 475
# self.num_stocks: 475
# rebalance_positions
# 755, 2014-02-27 23:59:59.999989, isowk 9, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-03-07 00:00:00
# rankings length: 475
# self.num_stocks: 475
# rebalance_portfolio
# 765, 2014-03-06 23:59:59.999989, isowk 10, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-03-14 00:00:00
# rankings length: 475
# self.num_stocks: 475
# rebalance_positions
# 775, 2014-03-13 23:59:59.999989, isowk 11, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-03-21 00:00:00
# rankings length: 475
# self.num_stocks: 475
# rebalance_portfolio
# 785, 2014-03-20 23:59:59.999989, isowk 12, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-03-28 00:00:00
# rankings length: 475
# self.num_stocks: 475
# rebalance_positions
# 795, 2014-03-27 23:59:59.999989, isowk 13, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-04-04 00:00:00
# rankings length: 508
# self.num_stocks: 508
# rebalance_portfolio
# 805, 2014-04-03 23:59:59.999989, isowk 14, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-04-11 00:00:00
# rankings length: 508
# self.num_stocks: 508
# rebalance_positions
# 815, 2014-04-10 23:59:59.999989, isowk 15, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-04-21 00:00:00
# rankings length: 508
# self.num_stocks: 508
# rebalance_portfolio
# 825, 2014-04-17 23:59:59.999989, isowk 16, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-04-25 00:00:00
# rankings length: 508
# self.num_stocks: 508
# rebalance_positions
# 833, 2014-04-24 23:59:59.999989, isowk 17, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-05-02 00:00:00
# rankings length: 509
# self.num_stocks: 509
# rebalance_portfolio
# 843, 2014-05-01 23:59:59.999989, isowk 18, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-05-09 00:00:00
# rankings length: 509
# self.num_stocks: 509
# rebalance_positions
# 853, 2014-05-08 23:59:59.999989, isowk 19, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-05-16 00:00:00
# rankings length: 509
# self.num_stocks: 509
# rebalance_portfolio
# 863, 2014-05-15 23:59:59.999989, isowk 20, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-05-23 00:00:00
# rankings length: 509
# self.num_stocks: 509
# rebalance_positions
# 873, 2014-05-22 23:59:59.999989, isowk 21, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-05-30 00:00:00
# rankings length: 516
# self.num_stocks: 516
# rebalance_portfolio
# 881, 2014-05-29 23:59:59.999989, isowk 22, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-06-06 00:00:00
# rankings length: 516
# self.num_stocks: 516
# rebalance_positions
# 891, 2014-06-05 23:59:59.999989, isowk 23, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-06-13 00:00:00
# rankings length: 516
# self.num_stocks: 516
# rebalance_portfolio
# 901, 2014-06-12 23:59:59.999989, isowk 24, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-06-20 00:00:00
# rankings length: 516
# self.num_stocks: 516
# rebalance_positions
# 911, 2014-06-19 23:59:59.999989, isowk 25, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-06-27 00:00:00
# rankings length: 516
# self.num_stocks: 516
# rebalance_portfolio
# 921, 2014-06-26 23:59:59.999989, isowk 26, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-07-07 00:00:00
# rankings length: 517
# self.num_stocks: 517
# rebalance_positions
# 931, 2014-07-03 23:59:59.999989, isowk 27, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-07-11 00:00:00
# rankings length: 517
# self.num_stocks: 517
# rebalance_portfolio
# 939, 2014-07-10 23:59:59.999989, isowk 28, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-07-18 00:00:00
# rankings length: 517
# self.num_stocks: 517
# rebalance_positions
# 949, 2014-07-17 23:59:59.999989, isowk 29, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-07-25 00:00:00
# rankings length: 517
# self.num_stocks: 517
# rebalance_portfolio
# 959, 2014-07-24 23:59:59.999989, isowk 30, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-08-01 00:00:00
# rankings length: 519
# self.num_stocks: 519
# rebalance_positions
# 969, 2014-07-31 23:59:59.999989, isowk 31, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-08-08 00:00:00
# rankings length: 519
# self.num_stocks: 519
# rebalance_portfolio
# 979, 2014-08-07 23:59:59.999989, isowk 32, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-08-15 00:00:00
# rankings length: 519
# self.num_stocks: 519
# rebalance_positions
# 989, 2014-08-14 23:59:59.999989, isowk 33, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-08-22 00:00:00
# rankings length: 519
# self.num_stocks: 519
# rebalance_portfolio
# 999, 2014-08-21 23:59:59.999989, isowk 34, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-08-29 00:00:00
# rankings length: 521
# self.num_stocks: 521
# rebalance_positions
# 1009, 2014-08-28 23:59:59.999989, isowk 35, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-09-05 00:00:00
# rankings length: 521
# self.num_stocks: 521
# rebalance_portfolio
# 1017, 2014-09-04 23:59:59.999989, isowk 36, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-09-12 00:00:00
# rankings length: 521
# self.num_stocks: 521
# rebalance_positions
# 1027, 2014-09-11 23:59:59.999989, isowk 37, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-09-19 00:00:00
# rankings length: 521
# self.num_stocks: 521
# rebalance_portfolio
# 1037, 2014-09-18 23:59:59.999989, isowk 38, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-09-26 00:00:00
# rankings length: 521
# self.num_stocks: 521
# rebalance_positions
# 1047, 2014-09-25 23:59:59.999989, isowk 39, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-10-03 00:00:00
# rankings length: 523
# self.num_stocks: 523
# rebalance_portfolio
# 1057, 2014-10-02 23:59:59.999989, isowk 40, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-10-10 00:00:00
# rankings length: 523
# self.num_stocks: 523
# rebalance_positions
# 1067, 2014-10-09 23:59:59.999989, isowk 41, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-10-17 00:00:00
# rankings length: 523
# self.num_stocks: 523
# rebalance_portfolio
# 1077, 2014-10-16 23:59:59.999989, isowk 42, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-10-24 00:00:00
# rankings length: 523
# self.num_stocks: 523
# rebalance_positions
# 1087, 2014-10-23 23:59:59.999989, isowk 43, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-10-31 00:00:00
# rankings length: 523
# self.num_stocks: 523
# rebalance_portfolio
# 1097, 2014-10-30 23:59:59.999989, isowk 44, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-11-07 00:00:00
# rankings length: 523
# self.num_stocks: 523
# rebalance_positions
# 1107, 2014-11-06 23:59:59.999989, isowk 45, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-11-14 00:00:00
# rankings length: 523
# self.num_stocks: 523
# rebalance_portfolio
# 1117, 2014-11-13 23:59:59.999989, isowk 46, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-11-21 00:00:00
# rankings length: 523
# self.num_stocks: 523
# rebalance_positions
# 1127, 2014-11-20 23:59:59.999989, isowk 47, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-11-28 00:00:00
# rankings length: 530
# self.num_stocks: 530
# rebalance_portfolio
# 1135, 2014-11-26 23:59:59.999989, isowk 48, isowkday 3, dayName: Wednesday
# strategy notify_timer with tid 0, when 2014-12-05 00:00:00
# rankings length: 530
# self.num_stocks: 530
# rebalance_positions
# 1145, 2014-12-04 23:59:59.999989, isowk 49, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-12-12 00:00:00
# rankings length: 530
# self.num_stocks: 530
# rebalance_portfolio
# 1155, 2014-12-11 23:59:59.999989, isowk 50, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-12-19 00:00:00
# rankings length: 530
# self.num_stocks: 530
# rebalance_positions
# 1165, 2014-12-18 23:59:59.999989, isowk 51, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2014-12-26 00:00:00
# rankings length: 530
# self.num_stocks: 530
# rebalance_portfolio
# 1173, 2014-12-24 23:59:59.999989, isowk 52, isowkday 3, dayName: Wednesday
# strategy notify_timer with tid 0, when 2015-01-02 00:00:00
# rankings length: 532
# self.num_stocks: 532
# rebalance_positions
# 1181, 2014-12-31 23:59:59.999989, isowk 1, isowkday 3, dayName: Wednesday
# strategy notify_timer with tid 0, when 2015-01-09 00:00:00
# rankings length: 532
# self.num_stocks: 532
# rebalance_portfolio
# 1191, 2015-01-08 23:59:59.999989, isowk 2, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-01-16 00:00:00
# rankings length: 532
# self.num_stocks: 532
# rebalance_positions
# 1201, 2015-01-15 23:59:59.999989, isowk 3, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-01-23 00:00:00
# rankings length: 532
# self.num_stocks: 532
# rebalance_portfolio
# 1209, 2015-01-22 23:59:59.999989, isowk 4, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-01-30 00:00:00
# rankings length: 534
# self.num_stocks: 534
# rebalance_positions
# 1219, 2015-01-29 23:59:59.999989, isowk 5, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-02-06 00:00:00
# rankings length: 534
# self.num_stocks: 534
# rebalance_portfolio
# 1229, 2015-02-05 23:59:59.999989, isowk 6, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-02-13 00:00:00
# rankings length: 534
# self.num_stocks: 534
# rebalance_positions
# 1239, 2015-02-12 23:59:59.999989, isowk 7, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-02-20 00:00:00
# rankings length: 534
# self.num_stocks: 534
# rebalance_portfolio
# 1247, 2015-02-19 23:59:59.999989, isowk 8, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-02-27 00:00:00
# rankings length: 534
# self.num_stocks: 534
# rebalance_positions
# 1257, 2015-02-26 23:59:59.999989, isowk 9, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-03-06 00:00:00
# rankings length: 534
# self.num_stocks: 534
# rebalance_portfolio
# 1267, 2015-03-05 23:59:59.999989, isowk 10, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-03-13 00:00:00
# rankings length: 534
# self.num_stocks: 534
# rebalance_positions
# 1277, 2015-03-12 23:59:59.999989, isowk 11, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-03-20 00:00:00
# rankings length: 534
# self.num_stocks: 534
# rebalance_portfolio
# 1287, 2015-03-19 23:59:59.999989, isowk 12, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-03-27 00:00:00
# rankings length: 534
# self.num_stocks: 534
# rebalance_positions
# 1297, 2015-03-26 23:59:59.999989, isowk 13, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-04-06 00:00:00
# rankings length: 540
# self.num_stocks: 540
# rebalance_portfolio
# 1307, 2015-04-02 23:59:59.999989, isowk 14, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-04-10 00:00:00
# rankings length: 540
# self.num_stocks: 540
# rebalance_positions
# 1315, 2015-04-09 23:59:59.999989, isowk 15, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-04-17 00:00:00
# rankings length: 540
# self.num_stocks: 540
# rebalance_portfolio
# 1325, 2015-04-16 23:59:59.999989, isowk 16, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-04-24 00:00:00
# rankings length: 540
# self.num_stocks: 540
# rebalance_positions
# 1335, 2015-04-23 23:59:59.999989, isowk 17, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-05-01 00:00:00
# rankings length: 542
# self.num_stocks: 542
# rebalance_portfolio
# 1345, 2015-04-30 23:59:59.999989, isowk 18, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-05-08 00:00:00
# rankings length: 542
# self.num_stocks: 542
# rebalance_positions
# 1355, 2015-05-07 23:59:59.999989, isowk 19, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-05-15 00:00:00
# rankings length: 542
# self.num_stocks: 542
# rebalance_portfolio
# 1365, 2015-05-14 23:59:59.999989, isowk 20, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015
isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-10-16 00:00:00
# rankings length: 555
# self.num_stocks: 555
# rebalance_portfolio
# 1579, 2015-10-15 23:59:59.999989, isowk 42, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-10-23 00:00:00
# rankings length: 555
# self.num_stocks: 555
# rebalance_positions
# 1589, 2015-10-22 23:59:59.999989, isowk 43, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-10-30 00:00:00
# rankings length: 556
# self.num_stocks: 556
# rebalance_portfolio
# 1599, 2015-10-29 23:59:59.999989, isowk 44, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-11-06 00:00:00
# rankings length: 556
# self.num_stocks: 556
# rebalance_positions
# 1609, 2015-11-05 23:59:59.999989, isowk 45, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-11-13 00:00:00
# rankings length: 556
# self.num_stocks: 556
# rebalance_portfolio
# 1619, 2015-11-12 23:59:59.999989, isowk 46, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-11-20 00:00:00
# rankings length: 556
# self.num_stocks: 556
# rebalance_positions
# 1629, 2015-11-19 23:59:59.999989, isowk 47, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-11-27 00:00:00
# rankings length: 556
# self.num_stocks: 556
# rebalance_portfolio
# 1637, 2015-11-25 23:59:59.999989, isowk 48, isowkday 3, dayName: Wednesday
# strategy notify_timer with tid 0, when 2015-12-04 00:00:00
# rankings length: 559
# self.num_stocks: 559
# rebalance_positions
# 1647, 2015-12-03 23:59:59.999989, isowk 49, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-12-11 00:00:00
# rankings length: 559
# self.num_stocks: 559
# rebalance_portfolio
# 1657, 2015-12-10 23:59:59.999989, isowk 50, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-12-18 00:00:00
# rankings length: 559
# self.num_stocks: 559
# rebalance_positions
# 1667, 2015-12-17 23:59:59.999989, isowk 51, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2015-12-28 00:00:00
# rankings length: 559
# self.num_stocks: 559
# rebalance_portfolio
# 1677, 2015-12-24 23:59:59.999989, isowk 52, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-01-04 00:00:00
# rankings length: 560
# self.num_stocks: 560
# rebalance_positions
# 1685, 2015-12-31 23:59:59.999989, isowk 53, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-01-08 00:00:00
# rankings length: 560
# self.num_stocks: 560
# rebalance_portfolio
# 1693, 2016-01-07 23:59:59.999989, isowk 1, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-01-15 00:00:00
# rankings length: 560
# self.num_stocks: 560
# rebalance_positions
# 1703, 2016-01-14 23:59:59.999989, isowk 2, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-01-22 00:00:00
# rankings length: 560
# self.num_stocks: 560
# rebalance_portfolio
# 1711, 2016-01-21 23:59:59.999989, isowk 3, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-01-29 00:00:00
# rankings length: 564
# self.num_stocks: 564
# rebalance_positions
# 1721, 2016-01-28 23:59:59.999989, isowk 4, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-02-05 00:00:00
# rankings length: 564
# self.num_stocks: 564
# rebalance_portfolio
# 1731, 2016-02-04 23:59:59.999989, isowk 5, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-02-12 00:00:00
# rankings length: 564
# self.num_stocks: 564
# rebalance_positions
# 1741, 2016-02-11 23:59:59.999989, isowk 6, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-02-19 00:00:00
# rankings length: 564
# self.num_stocks: 564
# rebalance_portfolio
# 1749, 2016-02-18 23:59:59.999989, isowk 7, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-02-26 00:00:00
# rankings length: 564
# self.num_stocks: 564
# rebalance_positions
# 1759, 2016-02-25 23:59:59.999989, isowk 8, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-03-04 00:00:00
# rankings length: 565
# self.num_stocks: 565
# rebalance_portfolio
# 1769, 2016-03-03 23:59:59.999989, isowk 9, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016
isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-08-12 00:00:00
# rankings length: 585
# self.num_stocks: 585
# rebalance_positions
# 1993, 2016-08-11 23:59:59.999989, isowk 32, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-08-19 00:00:00
# rankings length: 585
# self.num_stocks: 585
# rebalance_portfolio
# 2003, 2016-08-18 23:59:59.999989, isowk 33, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-08-26 00:00:00
# rankings length: 585
# self.num_stocks: 585
# rebalance_positions
# 2013, 2016-08-25 23:59:59.999989, isowk 34, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-09-02 00:00:00
# rankings length: 585
# self.num_stocks: 585
# rebalance_portfolio
# 2023, 2016-09-01 23:59:59.999989, isowk 35, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-09-09 00:00:00
# rankings length: 585
# self.num_stocks: 585
# rebalance_positions
# 2031, 2016-09-08 23:59:59.999989, isowk 36, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-09-16 00:00:00
# rankings length: 585
# self.num_stocks: 585
# rebalance_portfolio
# 2041, 2016-09-15 23:59:59.999989, isowk 37, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-09-23 00:00:00
# rankings length: 585
# self.num_stocks: 585
# rebalance_positions
# 2051, 2016-09-22 23:59:59.999989, isowk 38, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-09-30 00:00:00
# rankings length: 589
# self.num_stocks: 589
# rebalance_portfolio
# 2061, 2016-09-29 23:59:59.999989, isowk 39, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-10-07 00:00:00
# rankings length: 589
# self.num_stocks: 589
# rebalance_positions
# 2071, 2016-10-06 23:59:59.999989, isowk 40, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-10-14 00:00:00
# rankings length: 589
# self.num_stocks: 589
# rebalance_portfolio
# 2081, 2016-10-13 23:59:59.999989, isowk 41, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-10-21 00:00:00
# rankings length: 589
# self.num_stocks: 589
# rebalance_positions
# 2091, 2016-10-20 23:59:59.999989, isowk 42, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-10-28 00:00:00
# rankings length: 589
# self.num_stocks: 589
# rebalance_portfolio
# 2101, 2016-10-27 23:59:59.999989, isowk 43, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-11-04 00:00:00
# rankings length: 589
# self.num_stocks: 589
# rebalance_positions
# 2111, 2016-11-03 23:59:59.999989, isowk 44, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-11-11 00:00:00
# rankings length: 589
# self.num_stocks: 589
# rebalance_portfolio
# 2121, 2016-11-10 23:59:59.999989, isowk 45, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-11-18 00:00:00
# rankings length: 589
# self.num_stocks: 589
# rebalance_positions
# 2131, 2016-11-17 23:59:59.999989, isowk 46, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-11-25 00:00:00
# rankings length: 589
# self.num_stocks: 589
# rebalance_portfolio
# 2139, 2016-11-23 23:59:59.999989, isowk 47, isowkday 3, dayName: Wednesday
# strategy notify_timer with tid 0, when 2016-12-02 00:00:00
# rankings length: 590
# self.num_stocks: 590
# rebalance_positions
# 2149, 2016-12-01 23:59:59.999989, isowk 48, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-12-09 00:00:00
# rankings length: 590
# self.num_stocks: 590
# rebalance_portfolio
# 2159, 2016-12-08 23:59:59.999989, isowk 49, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-12-16 00:00:00
# rankings length: 590
# self.num_stocks: 590
# rebalance_positions
# 2169, 2016-12-15 23:59:59.999989, isowk 50, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-12-23 00:00:00
# rankings length: 590
# self.num_stocks: 590
# rebalance_portfolio
# 2179, 2016-12-22 23:59:59.999989, isowk 51, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2016-12-30 00:00:00
# rankings length: 592
# self.num_stocks: 592
# rebalance_positions
# 2187, 2016-12-29 23:59:59.999989, isowk 52, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-01-06 00:00:00
# rankings length: 592
# self.num_stocks: 592
# rebalance_portfolio
# 2195, 2017-01-05 23:59:59.999989, isowk 1, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-01-13 00:00:00
# rankings length: 592
# self.num_stocks: 592
# rebalance_positions
# 2205, 2017-01-12 23:59:59.999989, isowk 2, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-01-20 00:00:00
# rankings length: 592
# self.num_stocks: 592
# rebalance_portfolio
# 2213, 2017-01-19 23:59:59.999989, isowk 3, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-01-27 00:00:00
# rankings length: 592
# self.num_stocks: 592
# rebalance_positions
# 2223, 2017-01-26 23:59:59.999989, isowk 4, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-02-03 00:00:00
# rankings length: 593
# self.num_stocks: 593
# rebalance_portfolio
# 2233, 2017-02-02 23:59:59.999989, isowk 5, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-02-10 00:00:00
# rankings length: 593
# self.num_stocks: 593
# rebalance_positions
# 2243, 2017-02-09 23:59:59.999989, isowk 6, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-02-17 00:00:00
# rankings length: 593
# self.num_stocks: 593
# rebalance_portfolio
# 2253, 2017-02-16 23:59:59.999989, isowk 7, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-02-24 00:00:00
# rankings length: 593
# self.num_stocks: 593
# rebalance_positions
# 2261, 2017-02-23 23:59:59.999989, isowk 8, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-03-03 00:00:00
# rankings length: 595
# self.num_stocks: 595
# rebalance_portfolio
# 2271, 2017-03-02 23:59:59.999989, isowk 9, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-03-10 00:00:00
# rankings length: 595
# self.num_stocks: 595
# rebalance_positions
# 2281, 2017-03-09 23:59:59.999989, isowk 10, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-03-17 00:00:00
# rankings length: 595
# self.num_stocks: 595
# rebalance_portfolio
# 2291, 2017-03-16 23:59:59.999989, isowk 11, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-03-24 00:00:00
# rankings length: 595
# self.num_stocks: 595
# rebalance_positions
# 2301, 2017-03-23 23:59:59.999989, isowk 12, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-03-31 00:00:00
# rankings length: 600
# self.num_stocks: 600
# rebalance_portfolio
# 2311, 2017-03-30 23:59:59.999989, isowk 13, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-04-07 00:00:00
# rankings length: 600
# self.num_stocks: 600
# rebalance_positions
# 2321, 2017-04-06 23:59:59.999989, isowk 14, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-04-14 00:00:00
# rankings length: 600
# self.num_stocks: 600
# rebalance_portfolio
# 2331, 2017-04-13 23:59:59.999989, isowk 15, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-04-21 00:00:00
# rankings length: 600
# self.num_stocks: 600
# rebalance_positions
# 2340, 2017-04-20 23:59:59.999989, isowk 16, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-04-28 00:00:00
# rankings length: 602
# self.num_stocks: 602
# rebalance_portfolio
# 2350, 2017-04-27 23:59:59.999989, isowk 17, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-05-05 00:00:00
# rankings length: 602
# self.num_stocks: 602
# rebalance_positions
# 2360, 2017-05-04 23:59:59.999989, isowk 18, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-05-12 00:00:00
# rankings length: 602
# self.num_stocks: 602
# rebalance_portfolio
# 2370, 2017-05-11 23:59:59.999989, isowk 19, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-05-19 00:00:00
# rankings length: 602
# self.num_stocks: 602
# rebalance_positions
# 2380, 2017-05-18 23:59:59.999989, isowk 20, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-05-26 00:00:00
# rankings length: 602
# self.num_stocks: 602
# rebalance_portfolio
# 2390, 2017-05-25 23:59:59.999989, isowk 21, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-06-02 00:00:00
# rankings length: 602
# self.num_stocks: 602
# rebalance_positions
# 2398, 2017-06-01 23:59:59.999989, isowk 22, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-06-09 00:00:00
# rankings length: 602
# self.num_stocks: 602
# rebalance_portfolio
# 2408, 2017-06-08 23:59:59.999989, isowk 23, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-06-16 00:00:00
# rankings length: 602
# self.num_stocks: 602
# rebalance_positions
# 2418, 2017-06-15 23:59:59.999989, isowk 24, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-06-23 00:00:00
# rankings length: 602
# self.num_stocks: 602
# rebalance_portfolio
# 2428, 2017-06-22 23:59:59.999989, isowk 25, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-06-30 00:00:00
# rankings length: 607
# self.num_stocks: 607
# rebalance_positions
# 2438, 2017-06-29 23:59:59.999989, isowk 26, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-07-07 00:00:00
# rankings length: 607
# self.num_stocks: 607
# rebalance_portfolio
# 2446, 2017-07-06 23:59:59.999989, isowk 27, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-07-14 00:00:00
# rankings length: 607
# self.num_stocks: 607
# rebalance_positions
# 2456, 2017-07-13 23:59:59.999989, isowk 28, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-07-21 00:00:00
# rankings length: 607
# self.num_stocks: 607
# rebalance_portfolio
# 2466, 2017-07-20 23:59:59.999989, isowk 29, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-07-28 00:00:00
# rankings length: 607
# self.num_stocks: 607
# rebalance_positions
# 2476, 2017-07-27 23:59:59.999989, isowk 30, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-08-04 00:00:00
# rankings length: 613
# self.num_stocks: 613
# rebalance_portfolio
# 2486, 2017-08-03 23:59:59.999989, isowk 31, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-08-11 00:00:00
# rankings length: 613
# self.num_stocks: 613
# rebalance_positions
# 2496, 2017-08-10 23:59:59.999989, isowk 32, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-08-18 00:00:00
# rankings length: 613
# self.num_stocks: 613
# rebalance_portfolio
# 2506, 2017-08-17 23:59:59.999989, isowk 33, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-08-25 00:00:00
# rankings length: 613
# self.num_stocks: 613
# rebalance_positions
# 2516, 2017-08-24 23:59:59.999989, isowk 34, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-09-01 00:00:00
# rankings length: 616
# self.num_stocks: 616
# rebalance_portfolio
# 2526, 2017-08-31 23:59:59.999989, isowk 35, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-09-08 00:00:00
# rankings length: 616
# self.num_stocks: 616
# rebalance_positions
# 2534, 2017-09-07 23:59:59.999989, isowk 36, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-09-15 00:00:00
# rankings length: 616
# self.num_stocks: 616
# rebalance_portfolio
# 2544, 2017-09-14 23:59:59.999989, isowk 37, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-09-22 00:00:00
# rankings length: 616
# self.num_stocks: 616
# rebalance_positions
# 2554, 2017-09-21 23:59:59.999989, isowk 38, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-09-29 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_portfolio
# 2564, 2017-09-28 23:59:59.999989, isowk 39, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-10-06 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_positions
# 2574, 2017-10-05 23:59:59.999989, isowk 40, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-10-13 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_portfolio
# 2584, 2017-10-12 23:59:59.999989, isowk 41, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-10-20 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_positions
# 2594, 2017-10-19 23:59:59.999989, isowk 42, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-10-27 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_portfolio
# 2604, 2017-10-26 23:59:59.999989, isowk 43, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-11-03 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_positions
# 2614, 2017-11-02 23:59:59.999989, isowk 44, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-11-10 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_portfolio
# 2624, 2017-11-09 23:59:59.999989, isowk 45, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-11-17 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_positions
# 2634, 2017-11-16 23:59:59.999989, isowk 46, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-11-24 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_portfolio
# 2642, 2017-11-22 23:59:59.999989, isowk 47, isowkday 3, dayName: Wednesday
# strategy notify_timer with tid 0, when 2017-12-01 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_positions
# 2652, 2017-11-30 23:59:59.999989, isowk 48, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-12-08 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_portfolio
# 2662, 2017-12-07 23:59:59.999989, isowk 49, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-12-15 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_positions
# 2672, 2017-12-14 23:59:59.999989, isowk 50, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-12-22 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_portfolio
# 2682, 2017-12-21 23:59:59.999989, isowk 51, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2017-12-29 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_positions
# 2690, 2017-12-28 23:59:59.999989, isowk 52, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2018-01-05 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_portfolio
# 2698, 2018-01-04 23:59:59.999989, isowk 1, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2018-01-12 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_positions
# 2708, 2018-01-11 23:59:59.999989, isowk 2, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2018-01-19 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_portfolio
# 2716, 2018-01-18 23:59:59.999989, isowk 3, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2018-01-26 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_positions
# 2726, 2018-01-25 23:59:59.999989, isowk 4, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2018-02-02 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_portfolio
# 2736, 2018-02-01 23:59:59.999989, isowk 5, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2018-02-09 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_positions
# 2746, 2018-02-08 23:59:59.999989, isowk 6, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2018-02-16 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_portfolio
# 2756, 2018-02-15 23:59:59.999989, isowk 7, isowkday 4, dayName: Thursday
# strategy notify_timer with tid 0, when 2018-02-23 00:00:00
# rankings length: 618
# self.num_stocks: 618
# rebalance_positions
# 2764, 2018-02-22 23:59:59.999989, isowk 8, isowkday 4, dayName: Thursday

# %%
cerebro.plot(iplot=False)[0][0]
print(f"Sharpe: {results[0].analyzers.sharperatio.get_analysis()['sharperatio']:.3f}")
print(f"Norm. Annual Return: {results[0].analyzers.returns.get_analysis()['rnorm100']:.2f}%")
print(f"Max Drawdown: {results[0].analyzers.drawdown.get_analysis()['max']['drawdown']:.2f}%")
# Out:
# Sharpe: 0.833
# Norm. Annual Return: 9.11%
# Max Drawdown: 20.55%

# %%
cerebro.plot(iplot=False)[0][0]
print(f"Sharpe: {results[0].analyzers.sharperatio.get_analysis()['sharperatio']:.3f}")
print(f"Norm. Annual Return: {results[0].analyzers.returns.get_analysis()['rnorm100']:.2f}%")
print(f"Max Drawdown: {results[0].analyzers.drawdown.get_analysis()['max']['drawdown']:.2f}%")
# Out:
# Sharpe: 1.269
# Norm. Annual Return: 8.99%
# Max Drawdown: 11.71%

# %% [markdown]
# As we can see the algorithm performs pretty well. It makes an average of almost 9% a year with a max drawdown of only 11%. Although the S&P 500 slightly outperforms the algorithm over this time period (CAGR of 12%), it does so with more volatility (Max Drawdown of 13.5%, Sharpe of 1.07). Overall, this algorithm provides a good base for a momentum strategy and can likely be improved by altering parameters, applying filters, and adding leverage. I would highly recommend reading Clenow's book [Stocks on the Move: Beating the Market with Hedge Fund Momentum Strategy](https://amzn.to/2YzEIvL), as it provides a much more in depth description as to how the algorithm works, as well as detailed analysis of how it has performed historically.

# %% [markdown]
# If you would like to try the the strategy for yourself, you can find [this notebook](https://github.com/teddykoker/blog/tree/master/notebooks) on my Github, along with my [survivorship bias-free dataset](https://github.com/teddykoker/quant/tree/master/survivorship-free)!
